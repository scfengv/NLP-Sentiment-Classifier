# %%
import re
import nltk
import utils
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from os import getcwd
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords, twitter_samples
from utils import process_tweet, build_freqs, sigmoid, gradientDescent, test_logistic_regression, extract_features, predict_tweet

# %%
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shenchingfeng/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/shenchingfeng/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %% [markdown]
# ### Train-Test Split

# %%
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg 
test_x = test_pos + test_neg

# %%
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis = 0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis = 0)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ```python
# build_freqs(tweets, ys):
#     return freqs
# ```
#
# ```python
# tweets: a list of tweets
# ys: an m x 1 array with the sentiment label of each tweet (Positive: 1 ; Negative: 0)
# freqs: a dictionary mapping each (word, sentiment) pair to its frequency
# ```
#
# Calculate the frequency of specific word in Positive Tweet & Negative Tweet respectively

# %%
freqs = build_freqs(train_x, train_y)
freqs
# Out:
# {('followfriday', 1.0): 23,
#  ('france_int', 1.0): 1,
#  ('pkuchli', 1.0): 1,
#  ('57', 1.0): 2,
#  ('milipol_pari', 1.0): 1,
#  ('top', 1.0): 30,
#  ('engag', 1.0): 7,
#  ('member', 1.0): 14,
#  ('commun', 1.0): 27,
#  ('week', 1.0): 72,
#  (':)', 1.0): 2960,
#  ('lamb', 1.0): 1,
#  ('2ja', 1.0): 1,
#  ('hey', 1.0): 60,
#  ('jame', 1.0): 7,
#  ('odd', 1.0): 2,
#  (':/', 1.0): 5,
#  ('pleas', 1.0): 81,
#  ('call', 1.0): 27,
#  ('contact', 1.0): 4,
#  ('centr', 1.0): 1,
#  ('02392441234', 1.0): 1,
#  ('abl', 1.0): 6,
#  ('assist', 1.0): 1,
#  ('mani', 1.0): 28,
#  ('thank', 1.0): 522,
#  ('despiteoffici', 1.0): 1,
#  ('listen', 1.0): 15,
#  ('last', 1.0): 39,
#  ('night', 1.0): 55,
#  ('bleed', 1.0): 2,
#  ('amaz', 1.0): 41,
#  ('track', 1.0): 5,
#  ('scotland', 1.0): 2,
#  ('97side', 1.0): 1,
#  ('congrat', 1.0): 15,
#  ('yeaaah', 1.0): 1,
#  ('yipppi', 1.0): 1,
#  ('accnt', 1.0): 2,
#  ('verifi', 1.0): 2,
#  ('rqst', 1.0): 1,
#  ('succeed', 1.0): 1,
#  ('got', 1.0): 57,
#  ('blue', 1.0): 8,
#  ('tick', 1.0): 1,
#  ('mark', 1.0): 2,
#  ('fb', 1.0): 4,
#  ('profil', 1.0): 2,
#  ('15', 1.0): 7,
#  ('day', 1.0): 187,
#  ('bhaktisbant', 1.0): 16,
#  ('pallaviruhail', 1.0): 8,
#  ('one', 1.0): 92,
#  ('irresist', 1.0): 2,
#  ('flipkartfashionfriday', 1.0): 16,
#  ('like', 1.0): 187,
#  ('keep', 1.0): 55,
#  ('love', 1.0): 336,
#  ('custom', 1.0): 4,
#  ('wait', 1.0): 54,
#  ('long', 1.0): 27,
#  ('hope', 1.0): 115,
#  ('enjoy', 1.0): 61,
#  ('happi', 1.0): 162,
#  ('friday', 1.0): 91,
#  ('lwwf', 1.0): 1,
#  ('impatientraid', 1.0): 1,
#  ('second', 1.0): 8,
#  ('thought', 1.0): 21,
#  ('’', 1.0): 17,
#  ('enough', 1.0): 16,
#  ('time', 1.0): 101,
#  ('dd', 1.0): 1,
#  ('new', 1.0): 114,
#  ('short', 1.0): 6,
#  ('enter', 1.0): 9,
#  ('system', 1.0): 2,
#  ('sheep', 1.0): 1,
#  ('must', 1.0): 14,
#  ('buy', 1.0): 10,
#  ('jgh', 1.0): 4,
#  ('go', 1.0): 123,
#  ('bayan', 1.0): 1,
#  (':d', 1.0): 523,
#  ('bye', 1.0): 5,
#  ('act', 1.0): 6,
#  ('mischiev', 1.0): 1,
#  ('etl', 1.0): 1,
#  ('layer', 1.0): 1,
#  ('in-hous', 1.0): 1,
#  ('wareh', 1.0): 1,
#  ('app', 1.0): 12,
#  ('katamari', 1.0): 1,
#  ('well', 1.0): 66,
#  ('…', 1.0): 31,
#  ('name', 1.0): 12,
#  ('impli', 1.0): 1,
#  (':p', 1.0): 105,
#  ('wncer', 1.0): 1,
#  ('1', 1.0): 123,
#  ('defense_gouv', 1.0): 1,
#  ('influenc', 1.0): 16,
#  ('big', 1.0): 28,
#  ('...', 1.0): 228,
#  ('juici', 1.0): 3,
#  ('selfi', 1.0): 11,
#  ('mish', 1.0): 1,
#  ('2361535', 1.0): 1,
#  ('follow', 1.0): 385,
#  ('jnlazt', 1.0): 62,
#  ('u', 1.0): 204,
#  ('back', 1.0): 139,
#  ('jjulieredburn', 1.0): 1,
#  ('perfect', 1.0): 17,
#  ('alreadi', 1.0): 19,
#  ('know', 1.0): 128,
#  ("what'", 1.0): 14,
#  ('great', 1.0): 135,
#  ('opportun', 1.0): 17,
#  ('junior', 1.0): 2,
#  ('triathlet', 1.0): 1,
#  ('age', 1.0): 2,
#  ('12', 1.0): 8,
#  ('13', 1.0): 11,
#  ('gatorad', 1.0): 1,
#  ('seri', 1.0): 4,
#  ('get', 1.0): 166,
#  ('entri', 1.0): 3,
#  ('lay', 1.0): 3,
#  ('greet', 1.0): 4,
#  ('card', 1.0): 6,
#  ('rang', 1.0): 2,
#  ('print', 1.0): 4,
#  ('today', 1.0): 91,
#  ('job', 1.0): 34,
#  (':-)', 1.0): 552,
#  ("friend'", 1.0): 3,
#  ('lunch', 1.0): 3,
#  ('yummm', 1.0): 1,
#  ('nostalgia', 1.0): 1,
#  ('tb', 1.0): 1,
#  ('ku', 1.0): 1,
#  ('rookiesenpai', 1.0): 1,
#  ('arcadest', 1.0): 1,
#  ('id', 1.0): 8,
#  ('conflict', 1.0): 1,
#  ('help', 1.0): 40,
#  ("here'", 1.0): 20,
#  ('screenshot', 1.0): 2,
#  ('work', 1.0): 89,
#  ('oohdawg', 1.0): 1,
#  ('hi', 1.0): 154,
#  ('liv', 1.0): 2,
#  ('hello', 1.0): 49,
#  ('need', 1.0): 62,
#  ('someth', 1.0): 25,
#  ('fm', 1.0): 2,
#  ('twitter', 1.0): 25,
#  ('—', 1.0): 22,
#  ('sure', 1.0): 38,
#  ('thing', 1.0): 48,
#  ('dm', 1.0): 34,
#  ('x', 1.0): 50,
#  ('mbandscott', 1.0): 1,
#  ('eric_fl', 1.0): 1,
#  ('pointsolut', 1.0): 1,
#  ('3', 1.0): 40,
#  ('rossbreadmor', 1.0): 1,
#  ("i'v", 1.0): 25,
#  ('heard', 1.0): 9,
#  ('four', 1.0): 5,
#  ('season', 1.0): 5,
#  ('pretti', 1.0): 17,
#  ('dope', 1.0): 2,
#  ('penthous', 1.0): 1,
#  ('obv', 1.0): 1,
#  ('gobigorgohom', 1.0): 1,
#  ('fun', 1.0): 45,
#  ("y'all", 1.0): 4,
#  ('gculloti', 1.0): 4,
#  ('87', 1.0): 7,
#  ('yeah', 1.0): 30,
#  ('suppos', 1.0): 6,
#  ('lol', 1.0): 48,
#  ('chat', 1.0): 9,
#  ('bit', 1.0): 16,
#  ('youth', 1.0): 14,
#  ('tolajobjob', 1.0): 14,
#  ('maphisa', 1.0): 1,
#  ('301', 1.0): 1,
#  ('💅🏽', 1.0): 1,
#  ('💋', 1.0): 2,
#  ('seen', 1.0): 6,
#  ('year', 1.0): 33,
#  ('bosslog', 1.0): 1,
#  ('amellywood', 1.0): 1,
#  ('cw_arrow', 1.0): 1,
#  ('arrowwrit', 1.0): 1,
#  ('johngutierrez', 1.0): 1,
#  ('rest', 1.0): 9,
#  ('goe', 1.0): 4,
#  ('quickli', 1.0): 3,
#  ('bed', 1.0): 8,
#  ('music', 1.0): 15,
#  ('fix', 1.0): 6,
#  ('dream', 1.0): 17,
#  ('spiritu', 1.0): 1,
#  ('ritual', 1.0): 1,
#  ('festiv', 1.0): 7,
#  ('népal', 1.0): 1,
#  ('begin', 1.0): 4,
#  ('line-up', 1.0): 4,
#  ('left', 1.0): 10,
#  ('see', 1.0): 157,
#  ('ke7zum', 1.0): 1,
#  ('sarah', 1.0): 4,
#  ('send', 1.0): 18,
#  ('us', 1.0): 96,
#  ('email', 1.0): 22,
#  ('bitsybitdefender.com', 1.0): 1,
#  ("we'll", 1.0): 12,
#  ('asap', 1.0): 5,
#  ('izzkamilhalda', 1.0): 1,
#  ('kik', 1.0): 16,
#  ('hatessuc', 1.0): 1,
#  ('32429', 1.0): 1,
#  ('kikm', 1.0): 1,
#  ('lgbt', 1.0): 2,
#  ('tinder', 1.0): 1,
#  ('nsfw', 1.0): 1,
#  ('akua', 1.0): 1,
#  ('cumshot', 1.0): 1,
#  ('kalinwhit', 1.0): 3,
#  ('come', 1.0): 63,
#  ('hous', 1.0): 5,
#  ('nsn_supplement', 1.0): 1,
#  ('effect', 1.0): 2,
#  ('press', 1.0): 1,
#  ('releas', 1.0): 11,
#  ('distribut', 1.0): 1,
#  ('result', 1.0): 2,
#  ('link', 1.0): 14,
#  ('remov', 1.0): 3,
#  ('pressreleas', 1.0): 1,
#  ('newsdistribut', 1.0): 1,
#  ('bam', 1.0): 44,
#  ('barsandmelodi', 1.0): 44,
#  ('bestfriend', 1.0): 50,
#  ('969horan696', 1.0): 44,
#  ('lot', 1.0): 80,
#  ('warsaw', 1.0): 44,
#  ('<3', 1.0): 119,
#  ('x46', 1.0): 1,
#  ('everyon', 1.0): 45,
#  ('watch', 1.0): 32,
#  ('documentari', 1.0): 1,
#  ('earthl', 1.0): 1,
#  ('youtub', 1.0): 18,
#  ('jamiefigsxx', 1.0): 1,
#  ('michelbauza', 1.0): 1,
#  ('invataonlin', 1.0): 1,
#  ('support', 1.0): 25,
#  ('buuut', 1.0): 1,
#  ('oh', 1.0): 44,
#  ('leisuremarkltd', 1.0): 1,
#  ('noshandquaff', 1.0): 1,
#  ('aktarislam', 1.0): 1,
#  ('keanebrand', 1.0): 1,
#  ('heritagesilv', 1.0): 1,
#  ('look', 1.0): 111,
#  ('forward', 1.0): 20,
#  ('visit', 1.0): 25,
#  ('next', 1.0): 37,
#  ('letsgetmessi', 1.0): 1,
#  ('jo', 1.0): 1,
#  ('sehunshinedaili', 1.0): 1,
#  ('make', 1.0): 70,
#  ('feel', 1.0): 33,
#  ('better', 1.0): 40,
#  ('never', 1.0): 31,
#  ('anyon', 1.0): 7,
#  ('kpop', 1.0): 1,
#  ('flesh', 1.0): 1,
#  ('joyster', 1.0): 1,
#  ('2012', 1.0): 2,
#  ('cathstaincliff', 1.0): 1,
#  ('good', 1.0): 191,
#  ('girl', 1.0): 34,
#  ('best', 1.0): 49,
#  ('wish', 1.0): 29,
#  ('_kimimi', 1.0): 1,
#  ('reason', 1.0): 10,
#  ('epic', 1.0): 1,
#  ('soundtrack', 1.0): 1,
#  ('aquadesigngroup', 1.0): 1,
#  ('shout', 1.0): 11,
#  ('ad', 1.0): 10,
#  ('video', 1.0): 30,
#  ('playlist', 1.0): 5,
#  ('im', 1.0): 41,
#  ('twitch', 1.0): 8,
#  ('leagu', 1.0): 6,
#  ('4', 1.0): 35,
#  ('would', 1.0): 70,
#  ('dear', 1.0): 15,
#  ('jordan', 1.0): 1,
#  ('firdoz', 1.0): 1,
#  ('visitjordan', 1.0): 2,
#  ('dannyprol', 1.0): 1,
#  ('abnormal_ana', 1.0): 1,
#  ('92', 1.0): 5,
#  ('okay', 1.0): 31,
#  ('sssniperwolf', 1.0): 1,
#  ('fake', 1.0): 1,
#  ('gameplay', 1.0): 1,
#  (';)', 1.0): 22,
#  ('haha', 1.0): 44,
#  ('kid', 1.0): 13,
#  ('stuff', 1.0): 11,
#  ('dennislami', 1.0): 1,
#  ('dicle_aygur', 1.0): 1,
#  ('exactli', 1.0): 5,
#  ('product', 1.0): 11,
#  ('line', 1.0): 6,
#  ('etsi', 1.0): 1,
#  ('shop', 1.0): 12,
#  ('check', 1.0): 39,
#  ('boxroomcraft', 1.0): 1,
#  ('peakyourmind', 1.0): 1,
#  ('vacat', 1.0): 5,
#  ('groovinshawn', 1.0): 1,
#  ('recharg', 1.0): 1,
#  ('normal', 1.0): 5,
#  ('charger', 1.0): 2,
#  ('france_espana', 1.0): 1,
#  ('reglisse_menth', 1.0): 1,
#  ('cci_int', 1.0): 1,
#  ('asleep', 1.0): 7,
#  ('talk', 1.0): 38,
#  ('sooo', 1.0): 6,
#  ('someon', 1.0): 29,
#  ('text', 1.0): 12,
#  ('brynybrath', 1.0): 1,
#  ('smallcappi', 1.0): 1,
#  ('ye', 1.0): 60,
#  ('bet', 1.0): 6,
#  ("he'll", 1.0): 2,
#  ('fit', 1.0): 2,
#  ('hear', 1.0): 24,
#  ('speech', 1.0): 1,
#  ('piti', 1.0): 2,
#  ('green', 1.0): 2,
#  ('garden', 1.0): 5,
#  ('midnight', 1.0): 1,
#  ('sun', 1.0): 6,
#  ('beauti', 1.0): 45,
#  ('canal', 1.0): 1,
#  ('dasvidaniya', 1.0): 1,
#  ('till', 1.0): 16,
#  ('keithrparson', 1.0): 1,
#  ('scout', 1.0): 1,
#  ('sg', 1.0): 1,
#  ('futur', 1.0): 9,
#  ('wlan', 1.0): 1,
#  ('pro', 1.0): 4,
#  ('confer', 1.0): 1,
#  ('asia', 1.0): 1,
#  ('cecilie_hel', 1.0): 1,
#  ('420evilangel', 1.0): 1,
#  ('wazimotomet', 1.0): 1,
#  ('durooo', 1.0): 1,
#  ('spigranti', 1.0): 1,
#  ('chang', 1.0): 20,
#  ('lollipop', 1.0): 1,
#  ('🍭', 1.0): 1,
#  ('nez', 1.0): 1,
#  ('agnezmo', 1.0): 1,
#  ('littlemix', 1.0): 1,
#  ('elemaaan', 1.0): 1,
#  ('oley', 1.0): 1,
#  ('cowokaddict', 1.0): 1,
#  ('mama', 1.0): 1,
#  ('stand', 1.0): 6,
#  ('stronger', 1.0): 1,
#  ('macatangayapril', 1.0): 1,
#  ('tk_kjk_kndr', 1.0): 1,
#  ('boukendream', 1.0): 1,
#  ('god', 1.0): 14,
#  ('misti', 1.0): 1,
#  ('babi', 1.0): 18,
#  ('cute', 1.0): 22,
#  ('carcassdrop', 1.0): 1,
#  ('woohoo', 1.0): 3,
#  ("can't", 1.0): 31,
#  ('sign', 1.0): 9,
#  ('yet', 1.0): 12,
#  ('still', 1.0): 37,
#  ('think', 1.0): 54,
#  ('mka', 1.0): 5,
#  ('liam', 1.0): 5,
#  ('access', 1.0): 3,
#  ('syuhxdxtengku', 1.0): 1,
#  ('welcom', 1.0): 54,
#  ('stat', 1.0): 51,
#  ('arriv', 1.0): 57,
#  ('unfollow', 1.0): 53,
#  ('via', 1.0): 73,
#  ('sluttywif', 1.0): 1,
#  ('2', 1.0): 60,
#  ('surpris', 1.0): 10,
#  ('figur', 1.0): 5,
#  ('murtishaw', 1.0): 1,
#  ('aqui_fr', 1.0): 1,
#  ('frtechstartup', 1.0): 1,
#  ('happybirthdayemilybett', 1.0): 1,
#  ('emilybett', 1.0): 6,
#  ('sweet', 1.0): 16,
#  ('talent', 1.0): 4,
#  ('plan', 1.0): 21,
#  ('drain', 1.0): 1,
#  ('x123456789tine', 1.0): 2,
#  ('5sos_fahupd', 1.0): 3,
#  ('gotta', 1.0): 4,
#  ('timezon', 1.0): 1,
#  ('parent', 1.0): 4,
#  ('proud', 1.0): 11,
#  ('least', 1.0): 14,
#  ('mayb', 1.0): 17,
#  ('sometim', 1.0): 11,
#  ('grade', 1.0): 4,
#  ('al', 1.0): 3,
#  ('grand', 1.0): 4,
#  ('manila_bro', 1.0): 1,
#  ('chosen', 1.0): 1,
#  ('syazwanzain', 1.0): 1,
#  ('let', 1.0): 70,
#  ('around', 1.0): 14,
#  ('..', 1.0): 100,
#  ('side', 1.0): 13,
#  ('world', 1.0): 23,
#  ('eh', 1.0): 2,
#  ('take', 1.0): 30,
#  ('care', 1.0): 12,
#  ('micha', 1.0): 1,
#  ('1green', 1.0): 1,
#  ('superninjaalan', 1.0): 1,
#  ('doug_laney', 1.0): 1,
#  ('final', 1.0): 24,
#  ('fuck', 1.0): 20,
#  ('weekend', 1.0): 61,
#  ('real', 1.0): 18,
#  ('lolesportspedia', 1.0): 1,
#  ('x45', 1.0): 1,
#  ('join', 1.0): 21,
#  ('hushedcallwithfraydo', 1.0): 1,
#  ('gift', 1.0): 7,
#  ('_fraydo', 1.0): 1,
#  ('hushedapp', 1.0): 3,
#  ('yaslarri', 1.0): 1,
#  ('yeahhh', 1.0): 1,
#  ('hushedpinwithsammi', 1.0): 2,
#  ('event', 1.0): 8,
#  ('might', 1.0): 21,
#  ('sammywilk', 1.0): 2,
#  ('luv', 1.0): 4,
#  ('realli', 1.0): 66,
#  ('appreci', 1.0): 28,
#  ('share', 1.0): 41,
#  ('xhebenkewu', 1.0): 1,
#  ('_9920', 1.0): 1,
#  ('tompark', 1.0): 4,
#  ('wow', 1.0): 14,
#  ('tom', 1.0): 6,
#  ('darlingixhai', 1.0): 1,
#  ('22', 1.0): 7,
#  ('syreenann', 1.0): 1,
#  ('americanograin', 1.0): 1,
#  ('pecomep', 1.0): 1,
#  ('apaulicand', 1.0): 1,
#  ('zaynzaynmalik', 1.0): 1,
#  ('30', 1.0): 6,
#  ('gym', 1.0): 3,
#  ('monday', 1.0): 7,
#  ('harnilizaloui', 1.0): 1,
#  ('invit', 1.0): 15,
#  ('scope', 1.0): 5,
#  ('friend', 1.0): 43,
#  ('nude', 1.0): 1,
#  ('jacobwhitesid', 1.0): 1,
#  ('sleep', 1.0): 35,
#  ('birthday', 1.0): 53,
#  ('metalgear_jp', 1.0): 1,
#  ('kojima_hideo', 1.0): 1,
#  ('want', 1.0): 71,
#  ('t-shirt', 1.0): 2,
#  ('cool', 1.0): 29,
#  ('axerad', 1.0): 1,
#  ('haw', 1.0): 1,
#  ('phela', 1.0): 1,
#  ('mom', 1.0): 7,
#  ('obvious', 1.0): 1,
#  ('zaynmalik', 1.0): 3,
#  ('princ', 1.0): 1,
#  ('charm', 1.0): 1,
#  ('stage', 1.0): 2,
#  ('luck', 1.0): 26,
#  ('straz_da', 1.0): 1,
#  ('dcarsoncpa', 1.0): 1,
#  ('gh813600', 1.0): 1,
#  ('twentyonepilot', 1.0): 1,
#  ('fujirock_jp', 1.0): 1,
#  ('tyler', 1.0): 1,
#  ('hipster', 1.0): 1,
#  ('glass', 1.0): 3,
#  ('martyrafenstein', 1.0): 1,
#  ('marti', 1.0): 2,
#  ('glad', 1.0): 41,
#  ('ukbusinesslunch', 1.0): 1,
#  ('lafitnessukhelp', 1.0): 1,
#  ('done', 1.0): 40,
#  ('afternoon', 1.0): 7,
#  ('read', 1.0): 28,
#  ('kahfi', 1.0): 1,
#  ('finish', 1.0): 15,
#  ('ohmyg', 1.0): 1,
#  ('yaya', 1.0): 3,
#  ('dub', 1.0): 1,
#  ('mainedcm', 1.0): 1,
#  ('stalk', 1.0): 2,
#  ('ig', 1.0): 3,
#  ('gondooo', 1.0): 1,
#  ('moo', 1.0): 2,
#  ('tologooo', 1.0): 1,
#  ('rozbab', 1.0): 1,
#  ('becom', 1.0): 8,
#  ('detail', 1.0): 8,
#  ('ngourd', 1.0): 1,
#  ('locita', 1.0): 1,
#  ('d_robert_kelli', 1.0): 1,
#  ('kevinthewhippet', 1.0): 1,
#  ('cassie_spaniel', 1.0): 1,
#  ('bracken_nelson', 1.0): 1,
#  ('bellisimobella', 1.0): 1,
#  ('spanielharri', 1.0): 1,
#  ('zzz', 1.0): 1,
#  ('xx', 1.0): 33,
#  ('physiotherapi', 1.0): 1,
#  ('hashtag', 1.0): 3,
#  ('cjlopez', 1.0): 1,
#  ('21', 1.0): 9,
#  ('💪', 1.0): 1,
#  ('monica', 1.0): 1,
#  ('miss', 1.0): 17,
#  ('sound', 1.0): 20,
#  ('morn', 1.0): 68,
#  ("that'", 1.0): 49,
#  ('x43', 1.0): 1,
#  ('mandascapinello', 1.0): 1,
#  ('definit', 1.0): 20,
#  ('tri', 1.0): 34,
#  ('tonight', 1.0): 15,
#  ('took', 1.0): 7,
#  ('advic', 1.0): 6,
#  ('treviso', 1.0): 1,
#  ('morallosanthoni', 1.0): 1,
#  ('nikkieriozzi', 1.0): 1,
#  ('impastel', 1.0): 17,
#  ('concert', 1.0): 23,
#  ('citi', 1.0): 26,
#  ('countri', 1.0): 22,
#  ("i'll", 1.0): 74,
#  ('start', 1.0): 56,
#  ('fine', 1.0): 7,
#  ('gorgeou', 1.0): 9,
#  ('xo', 1.0): 2,
#  ('oven', 1.0): 2,
#  ('roast', 1.0): 1,
#  ('garlic', 1.0): 1,
#  ('oliv', 1.0): 1,
#  ('oil', 1.0): 4,
#  ('dri', 1.0): 4,
#  ('tomato', 1.0): 1,
#  ('basil', 1.0): 1,
#  ('centuri', 1.0): 1,
#  ('tuna', 1.0): 1,
#  ('hostmyoffic', 1.0): 1,
#  ('nigelpwhittak', 1.0): 1,
#  ('lemezma', 1.0): 1,
#  ('twbc_busi', 1.0): 2,
#  ('_thebunkerjl', 1.0): 1,
#  ('right', 1.0): 38,
#  ('atchya', 1.0): 1,
#  ('teamtal', 1.0): 1,
#  ('17', 1.0): 5,
#  ('flashhay', 1.0): 1,
#  ('even', 1.0): 26,
#  ('almost', 1.0): 8,
#  ('michelploria', 1.0): 1,
#  ('myfrenchc', 1.0): 1,
#  ('jasoncr', 1.0): 1,
#  ('chanc', 1.0): 3,
#  ('chiab', 1.0): 1,
#  ('2486', 1.0): 1,
#  ('mrclivec', 1.0): 1,
#  ('pcdkirkwood', 1.0): 1,
#  ('dc_arvsgt', 1.0): 1,
#  ('cops_presid', 1.0): 1,
#  ('emwilliamscccu', 1.0): 1,
#  ('laurargallagh', 1.0): 1,
#  ('hall', 1.0): 2,
#  ('11kate', 1.0): 1,
#  ('laminx', 1.0): 1,
#  ('541', 1.0): 1,
#  ('johntarbet', 1.0): 1,
#  ('71', 1.0): 4,
#  ('cheer', 1.0): 18,
#  ('thatguycalledp', 1.0): 1,
#  ('po', 1.0): 3,
#  ('ice', 1.0): 6,
#  ('cream', 1.0): 6,
#  ('19strawberry66', 1.0): 1,
#  ('agre', 1.0): 13,
#  ('100', 1.0): 6,
#  ('spazzytsukihara', 1.0): 4,
#  ('heheheh', 1.0): 2,
#  ('that', 1.0): 10,
#  ('point', 1.0): 11,
#  ('stay', 1.0): 21,
#  ('home', 1.0): 20,
#  ('digitalplac', 1.0): 1,
#  ('2be', 1.0): 1,
#  ('intlboost', 1.0): 1,
#  ('_lafontpress', 1.0): 1,
#  ('stayfaboo', 1.0): 1,
#  ('soon', 1.0): 38,
#  ('promis', 1.0): 4,
#  ('web', 1.0): 4,
#  ('whatsapp', 1.0): 3,
#  ('volta', 1.0): 1,
#  ('funcionar', 1.0): 1,
#  ('com', 1.0): 2,
#  ('iphon', 1.0): 7,
#  ('jailbroken', 1.0): 1,
#  ('crustyolddeen', 1.0): 2,
#  ('later', 1.0): 12,
#  ('34', 1.0): 5,
#  ('min', 1.0): 8,
#  ('leia', 1.0): 1,
#  ('appear', 1.0): 3,
#  ('hologram', 1.0): 1,
#  ('r2d2', 1.0): 1,
#  ('w', 1.0): 16,
#  ('messag', 1.0): 9,
#  ('obi', 1.0): 1,
#  ('wan', 1.0): 1,
#  ('sit', 1.0): 7,
#  ('luke', 1.0): 5,
#  ('mburu', 1.0): 1,
#  ('__', 1.0): 7,
#  ('inter', 1.0): 2,
#  ('ucl', 1.0): 1,
#  ('arsen', 1.0): 2,
#  ('small', 1.0): 2,
#  ('team', 1.0): 24,
#  ('pass', 1.0): 10,
#  ('🚂', 1.0): 1,
#  ('dewsburi', 1.0): 2,
#  ('railway', 1.0): 1,
#  ('station', 1.0): 4,
#  ('dew', 1.0): 1,
#  ('nationalrailenq', 1.0): 1,
#  ('west', 1.0): 1,
#  ('yorkshir', 1.0): 2,
#  ('clearlyarticl', 1.0): 1,
#  ('430', 1.0): 1,
#  ('smh', 1.0): 2,
#  ('uptommosass', 1.0): 1,
#  ('9:25', 1.0): 1,
#  ('live', 1.0): 23,
#  ('strang', 1.0): 4,
#  ('imagin', 1.0): 5,
#  ('megan', 1.0): 2,
#  ('bookmyshow', 1.0): 1,
#  ('masaantoday', 1.0): 4,
#  ('a4', 1.0): 3,
#  ('shweta', 1.0): 1,
#  ('tripathi', 1.0): 1,
#  ('wforwoman', 1.0): 10,
#  ('5', 1.0): 19,
#  ('20', 1.0): 7,
#  ('kurta', 1.0): 3,
#  ('half', 1.0): 6,
#  ('number', 1.0): 11,
#  ('wsalelov', 1.0): 14,
#  ('ah', 1.0): 12,
#  ('larri', 1.0): 3,
#  ('transworldbook', 1.0): 1,
#  ('anyway', 1.0): 14,
#  ('kinda', 1.0): 12,
#  ('goood', 1.0): 1,
#  ('jhun_hunyo', 1.0): 1,
#  ('life', 1.0): 36,
#  ('enn', 1.0): 1,
#  ('ojbj', 1.0): 1,
#  ('holmesjsamuel', 1.0): 1,
#  ('could', 1.0): 25,
#  ('warmup', 1.0): 1,
#  ('15th', 1.0): 2,
#  ('bath', 1.0): 6,
#  ('dum', 1.0): 2,
#  ('andar', 1.0): 1,
#  ('ram', 1.0): 1,
#  ('sampath', 1.0): 1,
#  ('sona', 1.0): 1,
#  ('mohapatra', 1.0): 1,
#  ('samantha', 1.0): 1,
#  ('edward', 1.0): 1,
#  ('mein', 1.0): 1,
#  ('tulan', 1.0): 1,
#  ('razi', 1.0): 2,
#  ('wah', 1.0): 2,
#  ('josh', 1.0): 1,
#  ('justinbieb', 1.0): 8,
#  ('alway', 1.0): 48,
#  ('smile', 1.0): 47,
#  ('darlakim', 1.0): 1,
#  ('pictur', 1.0): 7,
#  ('arsenalnewsasit', 1.0): 3,
#  ('16.20', 1.0): 1,
#  ('izywaylesexpat', 1.0): 1,
#  ('na4innov', 1.0): 1,
#  ('inxpresscoazur', 1.0): 1,
#  ('juleeyaanaa', 1.0): 1,
#  ('giveitup', 1.0): 1,
#  ('given', 1.0): 3,
#  ('ga', 1.0): 3,
#  ('subsidi', 1.0): 1,
#  ('initi', 1.0): 2,
#  ('propos', 1.0): 3,
#  ('delight', 1.0): 4,
#  ('dayloladay', 1.0): 1,
#  ('yesterday', 1.0): 4,
#  ('x42', 1.0): 1,
#  ('jaimeemelani', 1.0): 1,
#  ('lmaoo', 1.0): 2,
#  ('song', 1.0): 16,
#  ('ever', 1.0): 19,
#  ('shall', 1.0): 5,
#  ('littl', 1.0): 29,
#  ('throwback', 1.0): 3,
#  ('clazziebritcha', 1.0): 1,
#  ('outli', 1.0): 1,
#  ('island', 1.0): 2,
#  ('cheung', 1.0): 1,
#  ('chau', 1.0): 1,
#  ('mui', 1.0): 1,
#  ('wo', 1.0): 1,
#  ('total', 1.0): 6,
#  ('differ', 1.0): 10,
#  ('kfckitchentour', 1.0): 2,
#  ('kitchen', 1.0): 3,
#  ('clean', 1.0): 1,
#  ("i'm", 1.0): 140,
#  ('kfc_india', 1.0): 2,
#  ('cybelxxx', 1.0): 1,
#  ('jana', 1.0): 1,
#  ('7380', 1.0): 1,
#  ('cusp', 1.0): 1,
#  ('test', 1.0): 7,
#  ('water', 1.0): 7,
#  ('reward', 1.0): 1,
#  ('broadcastbeat', 1.0): 1,
#  ('insunwetrust', 1.0): 1,
#  ('conseilsmkg', 1.0): 1,
#  ('arummzz', 1.0): 2,
#  ("let'", 1.0): 20,
#  ('drive', 1.0): 9,
#  ('travel', 1.0): 19,
#  ('yogyakarta', 1.0): 3,
#  ('jeep', 1.0): 3,
#  ('indonesia', 1.0): 3,
#  ('instamood', 1.0): 3,
#  ('wanna', 1.0): 23,
#  ('skype', 1.0): 3,
#  ('agylyxa', 1.0): 1,
#  ('may', 1.0): 16,
#  ('nice', 1.0): 71,
#  ('friendli', 1.0): 1,
#  ('pretend', 1.0): 2,
#  ('film', 1.0): 8,
#  ('congratul', 1.0): 9,
#  ('amisharanka', 1.0): 1,
#  ('95', 1.0): 3,
#  ('winner', 1.0): 3,
#  ('cheesydelight', 1.0): 1,
#  ('contest', 1.0): 5,
#  ('address', 1.0): 8,
#  ('guy', 1.0): 48,
#  ('clararojasg', 1.0): 1,
#  ('bf_p', 1.0): 1,
#  ('2c', 1.0): 1,
#  ('mybusiness_plan', 1.0): 1,
#  ('puamagasiva', 1.0): 1,
#  ('market', 1.0): 5,
#  ('24/7', 1.0): 1,
#  ('regret', 1.0): 4,
#  ('vineshpom', 1.0): 1,
#  ('14', 1.0): 4,
#  ('hour', 1.0): 24,
#  ('leav', 1.0): 12,
#  ('without', 1.0): 9,
#  ('delay', 1.0): 1,
#  ('actual', 1.0): 13,
#  ('easi', 1.0): 7,
#  ('guess', 1.0): 8,
#  ('train', 1.0): 7,
#  ('wd', 1.0): 1,
#  ('shift', 1.0): 4,
#  ('engin', 1.0): 1,
#  ('etc', 1.0): 2,
#  ('sunburn', 1.0): 1,
#  ('peel', 1.0): 2,
#  ('sexdate_grati', 1.0): 1,
#  ('blog', 1.0): 27,
#  ('tikosd', 1.0): 1,
#  ('no1_razorstan', 1.0): 1,
#  ('cassthetrain', 1.0): 1,
#  ('huge', 1.0): 9,
#  ('warm', 1.0): 4,
#  ('vodkablond', 1.0): 2,
#  ('☆', 1.0): 3,
#  ('complet', 1.0): 10,
#  ('triangl', 1.0): 2,
#  ('luciennediv', 1.0): 1,
#  ('northern', 1.0): 1,
#  ('ireland', 1.0): 2,
#  ('sight', 1.0): 1,
#  ('mecastor', 1.0): 1,
#  ('01mica', 1.0): 1,
#  ('z_intl_ag', 1.0): 1,
#  ('tivipro', 1.0): 1,
#  ('compexli', 1.0): 1,
#  ('imraina', 1.0): 1,
#  ('smthng', 1.0): 2,
#  ('fr', 1.0): 3,
#  ('hug', 1.0): 11,
#  ('xoxo', 1.0): 3,
#  ('uu', 1.0): 1,
#  ('jaann', 1.0): 1,
#  ('topnewfollow', 1.0): 2,
#  ('bestofficpad', 1.0): 1,
#  ('mrcfluegel', 1.0): 1,
#  ('jeanmarcpn', 1.0): 1,
#  ('connect', 1.0): 13,
#  ('mooseallain', 1.0): 1,
#  ('meatbingo', 1.0): 4,
#  ('wonder', 1.0): 26,
#  ('made', 1.0): 38,
#  ('fluffi', 1.0): 1,
#  ('insid', 1.0): 7,
#  ('pirouett', 1.0): 1,
#  ('moos', 1.0): 1,
#  ('kristophcajon', 1.0): 1,
#  ('trip', 1.0): 12,
#  ('philli', 1.0): 1,
#  ('decemb', 1.0): 2,
#  ("i'd", 1.0): 13,
#  ('dude', 1.0): 6,
#  ('x41', 1.0): 1,
#  ('question', 1.0): 15,
#  ('flaw', 1.0): 1,
#  ('pain', 1.0): 8,
#  ('negat', 1.0): 1,
#  ('strength', 1.0): 2,
#  ('reflectkn', 1.0): 1,
#  ('went', 1.0): 10,
#  ('solo', 1.0): 4,
#  ('move', 1.0): 9,
#  ('fav', 1.0): 11,
#  ('nirvana', 1.0): 1,
#  ('smell', 1.0): 2,
#  ('teen', 1.0): 3,
#  ('spirit', 1.0): 1,
#  ('rip', 1.0): 3,
#  ('ami', 1.0): 5,
#  ('winehous', 1.0): 1,
#  ('ccidelyon', 1.0): 1,
#  ('cci', 1.0): 3,
#  ('_95', 1.0): 1,
#  ('cpneri_esigroup', 1.0): 1,
#  ('coupl', 1.0): 5,
#  ('tomhiddleston', 1.0): 1,
#  ('elizabetholsen', 1.0): 1,
#  ('yaytheylookgreat', 1.0): 1,
#  ('goodnight', 1.0): 18,
#  ('vid', 1.0): 8,
#  ('wake', 1.0): 10,
#  ('gonna', 1.0): 16,
#  ('shoot', 1.0): 5,
#  ('narakubrock', 1.0): 1,
#  ('itti', 1.0): 2,
#  ('bitti', 1.0): 2,
#  ('teeni', 1.0): 2,
#  ('bikini', 1.0): 3,
#  ('much', 1.0): 73,
#  ('4th', 1.0): 4,
#  ('togeth', 1.0): 6,
#  ('end', 1.0): 13,
#  ('xfile', 1.0): 1,
#  ('content', 1.0): 3,
#  ('aangelayap', 1.0): 1,
#  ('nttownend', 1.0): 1,
#  ('rain', 1.0): 18,
#  ('reyesfraulein', 1.0): 1,
#  ('fatpunkstudio', 1.0): 1,
#  ('fabul', 1.0): 4,
#  ('fantast', 1.0): 9,
#  ('caitecat', 1.0): 1,
#  ('1209', 1.0): 1,
#  ('♡', 1.0): 12,
#  ('jb', 1.0): 1,
#  ('forev', 1.0): 5,
#  ('belieb', 1.0): 3,
#  ('diplomix', 1.0): 1,
#  ('cci_entrepris', 1.0): 1,
#  ('_92', 1.0): 1,
#  ('franchiseedsuk', 1.0): 2,
#  ('lusciouslynde', 1.0): 1,
#  ('nighti', 1.0): 1,
#  ('bug', 1.0): 2,
#  ('bite', 1.0): 1,
#  ('bonsplansblog', 1.0): 1,
#  ('bracelet', 1.0): 2,
#  ('idea', 1.0): 24,
#  ('guywilliamsguy', 1.0): 1,
#  ('foundri', 1.0): 1,
#  ('game', 1.0): 23,
#  ('suzannepant', 1.0): 1,
#  ('kevinbacon', 1.0): 1,
#  ('katosman', 1.0): 1,
#  ('sens', 1.0): 6,
#  ('pic', 1.0): 21,
#  ('ef', 1.0): 1,
#  ('phone', 1.0): 16,
#  ('woot', 1.0): 2,
#  ('derek_gta', 1.0): 1,
#  ('derek', 1.0): 1,
#  ('use', 1.0): 32,
#  ('parkshar', 1.0): 1,
#  ('gloucestershir', 1.0): 1,
#  ('aaaahhh', 1.0): 1,
#  ('man', 1.0): 16,
#  ('traffic', 1.0): 2,
#  ('stress', 1.0): 4,
#  ('reliev', 1.0): 1,
#  ('elev', 1.0): 1,
#  ('joussotfrench_j', 1.0): 1,
#  ('nyibf', 1.0): 1,
#  ('el1new', 1.0): 1,
#  ("how'r", 1.0): 1,
#  ('jesutomisin', 1.0): 1,
#  ('arbeloa', 1.0): 1,
#  ('shawnmend', 1.0): 1,
#  ('turn', 1.0): 14,
#  ('omg', 1.0): 13,
#  ('matteomeacci', 1.0): 1,
#  ('say', 1.0): 43,
#  ('europ', 1.0): 1,
#  ('rise', 1.0): 2,
#  ('find', 1.0): 22,
#  ('hard', 1.0): 9,
#  ('believ', 1.0): 7,
#  ('uncount', 1.0): 1,
#  ('coz', 1.0): 2,
#  ('unlimit', 1.0): 1,
#  ('cours', 1.0): 11,
#  ('teamposit', 1.0): 1,
#  ('aldub', 1.0): 2,
#  ('coffeebreak', 1.0): 1,
#  ('laurenarren', 1.0): 1,
#  ('drparkav', 1.0): 1,
#  ('jwkanyuira', 1.0): 1,
#  ('1969', 1.0): 2,
#  ('dherac', 1.0): 1,
#  ('rhoachri', 1.0): 1,
#  ('barbarabathurst', 1.0): 1,
#  ('1cryingey', 1.0): 1,
#  ('willisteam', 1.0): 1,
#  ('☕', 1.0): 3,
#  ('rita', 1.0): 2,
#  ('mikerobb', 1.0): 1,
#  ('info', 1.0): 11,
#  ("we'd", 1.0): 4,
#  ('24gooch', 1.0): 1,
#  ('way', 1.0): 34,
#  ('boy', 1.0): 13,
#  ('graphur', 1.0): 2,
#  ('x40', 1.0): 1,
#  ('acbm_secem', 1.0): 1,
#  ('dcarsoncpa_nyc', 1.0): 1,
#  ...}

# %% [markdown]
# # Model Training

# %%
X = np.zeros((len(train_x), 3))

for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

Y = train_y

# %%
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, int(1e4))

print(f"The cost after training is {J:.4f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# The cost after training is 0.1013.
# The resulting vector of weights is [3e-07, 0.00127474, -0.0011083]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define a range of alpha and num_iters values to explore
alpha_values = [1e-7, 1e-8, 1e-9, 1e-10]
num_iters_values = [2000, 20000, 2000000]

# Create a grid of alpha and num_iters values
alpha, num_iters = np.meshgrid(alpha_values, num_iters_values)

# Initialize an empty array to store the corresponding cost values
cost_values = np.zeros_like(alpha)

# Perform gradient descent for each combination of alpha and num_iters
for i in range(len(alpha_values)):
    for j in range(len(num_iters_values)):
        J, _ = gradientDescent(X, Y, np.zeros((3, 1)), alpha[i, j], int(num_iters[i, j]))
        cost_values[i, j] = J

# Create a contour plot
plt.figure(figsize=(10, 6))
contour = plt.contourf(alpha, num_iters, cost_values, levels=20, cmap='viridis')
plt.colorbar(contour, label='Cost (J)')
plt.xlabel('Learning Rate (alpha)')
plt.ylabel('Number of Iterations (num_iters)')
plt.title('Cost vs. Learning Rate and Number of Iterations')
plt.show()
# Out:
# /Users/shenchingfeng/NLP-Sentiment Classifier/utils.py:146: RuntimeWarning: divide by zero encountered in log
#   J = -1/m * (np.dot(y.T, np.log(h)) + np.dot((1 - y).T, np.log(1 - h)))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/shenchingfeng/NLP-Sentiment Classifier/Logistic Regression.ipynb 儲存格 13 line 1
#      <a href='vscode-notebook-cell:/Users/shenchingfeng/NLP-Sentiment%20Classifier/Logistic%20Regression.ipynb#X52sZmlsZQ%3D%3D?line=14'>15</a> for i in range(len(alpha_values)):
#      <a href='vscode-notebook-cell:/Users/shenchingfeng/NLP-Sentiment%20Classifier/Logistic%20Regression.ipynb#X52sZmlsZQ%3D%3D?line=15'>16</a>     for j in range(len(num_iters_values)):
# ---> <a href='vscode-notebook-cell:/Users/shenchingfeng/NLP-Sentiment%20Classifier/Logistic%20Regression.ipynb#X52sZmlsZQ%3D%3D?line=16'>17</a>         J, _ = gradientDescent(X, Y, np.zeros((3, 1)), alpha[i, j], int(num_iters[i, j]))
#      <a href='vscode-notebook-cell:/Users/shenchingfeng/NLP-Sentiment%20Classifier/Logistic%20Regression.ipynb#X52sZmlsZQ%3D%3D?line=17'>18</a>         cost_values[i, j] = J
#      <a href='vscode-notebook-cell:/Users/shenchingfeng/NLP-Sentiment%20Classifier/Logistic%20Regression.ipynb#X52sZmlsZQ%3D%3D?line=19'>20</a> # Create a contour plot
#
# File ~/NLP-Sentiment Classifier/utils.py:146, in gradientDescent(x, y, theta, alpha, num_iters)
#     142     z = np.dot(x, theta)
#     144     h = sigmoid(z)
# --> 146     J = -1/m * (np.dot(y.T, np.log(h)) + np.dot((1 - y).T, np.log(1 - h)))
#     148     theta = theta - alpha/m * (np.dot(x.T, (h - y)))
#     150 J = float(J)
#
# KeyboardInterrupt:

# %% [markdown]
# # Model Testing

# %%
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print('%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# I am happy -> 0.799225
# I am bad -> 0.422531
# this movie should have been great. -> 0.763367
# great -> 0.759815
# great great -> 0.908929
# great great great -> 0.969219
# great great great great -> 0.990034

# %%
vali_tweet = [

    "Another day, another opportunity.",

    "Do the right things, do things right.",

    "Celebrate the journey, not just the destination.",

    "Every sunset is an opportunity to reset.",

    "Stars can not shine without darkness.",

    "Inhale courage, exhale fear.",

    "Radiate kindness like sunshine.",

    "Find beauty in the ordinary.",

    "Chase your wildest dreams with the heart of a lion.",

    "Life is a canvas; make it a masterpiece.",

    "Let your soul sparkle.",

    "Create your own sunshine.", 

    "This summer would not be perfect without you." ]


for tweet in vali_tweet:
    print('Stem:', process_tweet(tweet))
    print('%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
    print('\n')
# Out:
# Stem: ['anoth', 'day', 'anoth', 'opportun']
# Another day, another opportunity. -> 0.725077
#
#
# Stem: ['right', 'thing', 'thing', 'right']
# Do the right things, do things right. -> 0.558169
#
#
# Stem: ['celebr', 'journey', 'destin']
# Celebrate the journey, not just the destination. -> 0.504761
#
#
# Stem: ['everi', 'sunset', 'opportun', 'reset']
# Every sunset is an opportunity to reset. -> 0.567657
#
#
# Stem: ['star', 'shine', 'without', 'dark']
# Stars can not shine without darkness. -> 0.499589
#
#
# Stem: ['inhal', 'courag', 'exhal', 'fear']
# Inhale courage, exhale fear. -> 0.501253
#
#
# Stem: ['radiat', 'kind', 'like', 'sunshin']
# Radiate kindness like sunshine. -> 0.606686
#
#
# Stem: ['find', 'beauti', 'ordinari']
# Find beauty in the ordinary. -> 0.547009
#
#
# Stem: ['chase', 'wildest', 'dream', 'heart', 'lion']
# Chase your wildest dreams with the heart of a lion. -> 0.472705
#
#
# Stem: ['life', 'canva', 'make', 'masterpiec']
# Life is a canvas; make it a masterpiece. -> 0.508972
#
#
# Stem: ['let', 'soul', 'sparkl']
# Let your soul sparkle. -> 0.605789
#
#
# Stem: ['creat', 'sunshin']
# Create your own sunshine. -> 0.520965
#
#
# Stem: ['summer', 'would', 'perfect', 'without']
# This summer would not be perfect without you. -> 0.570600

# %%
accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.9945
